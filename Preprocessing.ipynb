# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('UCI.csv')

# %%
data.dtypes
# Out:
# tBodyAcc-mean()-X                       float64
# tBodyAcc-mean()-Y                       float64
# tBodyAcc-mean()-Z                       float64
# tBodyAcc-std()-X                        float64
# tBodyAcc-std()-Y                        float64
#                                          ...
# angle(tBodyGyroJerkMean,gravityMean)    float64
# angle(X,gravityMean)                    float64
# angle(Y,gravityMean)                    float64
# angle(Z,gravityMean)                    float64
# Activity                                 object
# Length: 562, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 44.2+ MB

# %%
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy.stats import skew, kurtosis

# Load the dataset
data = pd.read_csv('UCI.csv')

# Drop non-numeric columns (if 'Activity' is the only non-numeric one)
X = data.drop('Activity', axis=1)
y = data['Activity']

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Feature Engineering
def generate_features(df):
    feature_df = pd.DataFrame()

    # Mean, Std, Min, Max
    feature_df['mean'] = df.mean(axis=1)
    feature_df['std'] = df.std(axis=1)
    feature_df['min'] = df.min(axis=1)
    feature_df['max'] = df.max(axis=1)

    # Skewness and Kurtosis
    feature_df['skewness'] = df.apply(skew, axis=1)
    feature_df['kurtosis'] = df.apply(kurtosis, axis=1)

    # Signal Magnitude Area (SMA) - useful for accelerometer/gyroscope data
    feature_df['sma'] = df.abs().sum(axis=1)

    # Root Mean Square (RMS)
    feature_df['rms'] = np.sqrt(np.mean(df**2, axis=1))

    # Energy (sum of squares)
    feature_df['energy'] = np.sum(df**2, axis=1)

    return feature_df

# Generate new features
feature_engineered_data = generate_features(X)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(feature_engineered_data)

# Convert back to DataFrame for clarity
X_final = pd.DataFrame(X_scaled, columns=feature_engineered_data.columns)

# Display the new feature set
X_final.head()
# Out:
#        mean       std       min       max  skewness  kurtosis       sma  \
# 0 -0.719537  2.392656 -0.026593  0.865255  0.923570  0.694975  1.110627
# 1 -0.921940  0.851832 -0.026593  0.773527  0.916559  1.058530  0.901059
# 2 -0.952310  0.677951 -0.026593  0.773527  0.920928  1.077118  0.898675
# 3 -0.988893  0.750192 -0.026593  0.865255  1.055197  1.376763  0.968840
# 4 -0.965803  0.785684 -0.026593  0.784076  0.994644  1.182154  0.982215
#
#         rms    energy
# 0  1.043645  1.083009
# 1  0.944941  0.964100
# 2  0.943096  0.961893
# 3  0.990418  1.018674
# 4  0.974722  0.999798

# %%
import numpy as np

# FFT Feature Engineering
def generate_fft_features(df):
    fft_features = pd.DataFrame()

    # Compute FFT for each row
    fft_values = np.fft.fft(df, axis=1)
    fft_magnitude = np.abs(fft_values)

    # FFT-Based Features
    fft_features['fft_mean'] = np.mean(fft_magnitude, axis=1)
    fft_features['fft_std'] = np.std(fft_magnitude, axis=1)
    fft_features['fft_max'] = np.max(fft_magnitude, axis=1)
    fft_features['fft_min'] = np.min(fft_magnitude, axis=1)

    # Dominant Frequency (peak frequency)
    fft_features['dominant_freq'] = np.argmax(fft_magnitude, axis=1)

    return fft_features

# %%
# Display dataset size in the desired format
print(f"*Dataset Size:* {data.shape[0]} rows × {data.shape[1]} columns")
# Out:
# *Dataset Size:* 10299 rows × 562 columns

# %%
# Class distribution
class_distribution = data['Activity'].value_counts()

# Display in the desired format
print("*Class Distribution:*")
for activity, count in class_distribution.items():
    print(f"{activity}: {count}")
# Out:
# *Class Distribution:*
# LAYING: 1944
# STANDING: 1906
# SITTING: 1777
# WALKING: 1722
# WALKING_UPSTAIRS: 1544
# WALKING_DOWNSTAIRS: 1406

# %%
# Calculate missing data
missing_data = data.isnull().sum()

# Filter only columns with missing values
missing_data = missing_data[missing_data > 0]

# Display results
if missing_data.empty:
    print("🔹 *Missing Data:* None")
else:
    print("🔹 *Missing Data:*")
    for column, count in missing_data.items():
        print(f"{column}: {count} missing values")
# Out:
# 🔹 *Missing Data:* None

# %%
from sklearn.preprocessing import LabelEncoder

# Encode 'Activity' column
label_encoder = LabelEncoder()
data['Activity'] = label_encoder.fit_transform(data['Activity'])

# %%
from sklearn.preprocessing import StandardScaler

# Standardizing numeric features
X = data.drop('Activity', axis=1)
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
import numpy as np
from scipy.stats import skew, kurtosis

# Feature Engineering
X_scaled['mean'] = X.mean(axis=1)
X_scaled['std'] = X.std(axis=1)
X_scaled['skewness'] = X.apply(skew, axis=1)
X_scaled['kurtosis'] = X.apply(kurtosis, axis=1)
X_scaled['sma'] = np.abs(X).sum(axis=1)
X_scaled['rms'] = np.sqrt((X**2).mean(axis=1))

# %%
# Display column names
print(data.columns.tolist())
# Out:
# ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z', 'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z', 'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z', 'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y', 'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y', 'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y', 'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1', 'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3', 'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1', 'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3', 'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1', 'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3', 'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y', 'tBodyAcc-correlation()-X,Z', 'tBodyAcc-correlation()-Y,Z', 'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-mean()-Z', '
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy import stats

# Load the dataset
df = pd.read_csv("UCI.csv")

# Step 1: Handle Missing Values
# Separate numeric and categorical columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = SimpleImputer(strategy='mean').fit_transform(df[numeric_cols])

categorical_cols = df.select_dtypes(exclude=[np.number]).columns
df[categorical_cols] = SimpleImputer(strategy='most_frequent').fit_transform(df[categorical_cols])

# Step 2: Encode Categorical Variables
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# Step 3: Remove Outliers using Z-score
z_scores = np.abs(stats.zscore(df[numeric_cols]))
df = df[(z_scores < 3).all(axis=1)]

# Step 4: Scale Features
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Step 5: Remove Duplicates
df.drop_duplicates(inplace=True)

print("Preprocessing complete. Dataset shape:", df.shape)
# Out:
# Preprocessing complete. Dataset shape: (3818, 562)

# %%
# Save the preprocessed dataset
df.to_csv("UCI_preprocessed.csv", index=False)
print("Preprocessed dataset saved as 'UCI_preprocessed.csv'")
# Out:
# Preprocessed dataset saved as 'UCI_preprocessed.csv'

# %%
print(df.columns)
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)
